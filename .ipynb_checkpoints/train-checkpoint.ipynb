# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv('/content/drive/My Drive/BANGKIT/your_file_updated.csv')

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()

df1['Food Score']= label_encoder.fit_transform(df1['Food Score'])

df1['Food Score'].unique()
# Out:
# array([2, 3, 0, 1])

# %%
corr = df1.corr()
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.3) | (corr <= -0.3)], cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,annot=True, annot_kws={"size": 8}, square=True);

# %%
X = df1[['calories', 'proteins', 'fat', 'carbohydrate']]
y = df1[['Food Score']]

# %%
from sklearn.preprocessing import StandardScaler
PredictorScaler=StandardScaler()

PredictorScalerFit=PredictorScaler.fit(X)

X=PredictorScalerFit.transform(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (942, 4)
# (942, 1)
# (404, 4)
# (404, 1)

# %%
# train linear SVM classifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(X_train, y_train)
svm_predictions = svm_model_linear.predict(X_test)

# accuracy X_test
accuracy = svm_model_linear.score(X_test, y_test)
print(accuracy)

# confusion matrix
cm = confusion_matrix(y_test, svm_predictions)
print(cm)
# Out:
# 0.7945544554455446
# [[ 24   8   0   0]
#  [  2 168   4   0]
#  [  0  23 112  13]
#  [  0   0  33  17]]

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

f1 = f1_score(y_test, svm_predictions, average='weighted')
recall = recall_score(y_test, svm_predictions, average='weighted')
precision = precision_score(y_test, svm_predictions, average='weighted')

print("F1-score:", f1)
print("Recall:", recall)
print("Precision:", precision)
# Out:
# F1-score: 0.7824148530304019
# Recall: 0.7945544554455446
# Precision: 0.782214330151621

# %%
import joblib

# Save model
model_filename = '/content/drive/My Drive/BANGKIT/svm_model_linear.joblib'
joblib.dump(svm_model_linear, model_filename)

print(f"Model saved to {model_filename}")
# Out:
# Model saved to /content/drive/My Drive/BANGKIT/svm_model_linear.joblib
